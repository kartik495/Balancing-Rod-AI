# %%
import pygame
from math import cos,sin,pi
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv3D,MaxPool3D,Flatten
import cv2
import numpy as np
from tensorflow.keras import initializers
import random
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class AI():
    def __init__(self,game_time=80,replay_memory_limit=5,angle=pi/2,theta=pi/4,frame_input_limit=2,training_epochs=1,decision_factor=1,increment_factor=1,max_decision_factor=40):
        self.base_x=175
        self.base_y=300
        self.base_height=25
        self.base_width=50
        self.base_velocity=10
        self.line_length=64
        self.velocity=0
        self.theta=theta
        self.acceleration=cos(self.theta)
        self.line_top=(self.base_x+self.base_width//2 +self.line_length*cos(self.theta),self.base_y+self.base_height//2-self.line_length*sin(self.theta))
        self.run=True
        self.game_time=game_time
        self.score=0
        self.angle=angle
        self.replay_memory_limit=replay_memory_limit
        self.frame_input_limit=frame_input_limit
        self.current_state_index=0
        self.training_epochs=training_epochs
        self.current_state=np.empty((frame_input_limit,2*self.line_length,2*self.line_length))
        self.train_input_data=np.empty((replay_memory_limit,2*self.line_length,2*self.line_length,frame_input_limit,1))
        self.train_output_data=np.empty((replay_memory_limit,2))
        self.current_action=0
        self.previous_action=0
        self.decision_factor=decision_factor
        self.increment_factor=increment_factor
        self.max_decision_factor=max_decision_factor
        
        #creating and initializing model
        self.model=Sequential()
        self.model.add(Conv3D(8,(3,3,2),kernel_initializer=initializers.RandomNormal(stddev=0.1,mean=0),padding='same',activation='relu',input_shape=(2*self.line_length,2*self.line_length,2,1)))
        self.model.add(MaxPool3D((2,2,2)))
        self.model.add(Conv3D(4,(3,3,1),kernel_initializer=initializers.RandomNormal(stddev=0.1,mean=0),padding='same',activation='relu'))
        self.model.add(MaxPool3D((2,2,1)))
        self.model.add(Conv3D(2,(3,3,1),kernel_initializer=initializers.RandomNormal(stddev=0.1,mean=0),padding='same',activation='relu'))
        self.model.add(MaxPool3D((2,2,1)))
        self.model.add(Flatten())
        self.model.add(Dense(10,kernel_initializer=initializers.RandomNormal(stddev=0.1,mean=0),activation='tanh'))
        self.model.add(Dense(2,kernel_initializer=initializers.RandomNormal(stddev=0.1,mean=0),activation='tanh'))
        
    def get_screen(self,screen):
        rect = pygame.Rect(self.base_x+self.base_width//2-self.line_length,self.base_y+self.base_height//2-self.line_length,2*self.line_length,2*self.line_length)
        sub_screen = screen.subsurface(rect)
        pygame.image.save(sub_screen,'replay_memory/'+str(self.current_state_index)+'.jpg')
        
    def train(self):
        self.model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])
        self.model.fit(self.train_input_data,self.train_output_data,epochs=self.training_epochs,batch_size=1,shuffle=True)
    
    def state(self):
        for i in range(self.frame_input_limit):    
            self.current_state[i]=cv2.imread('replay_memory/'+str(self.current_state_index+i)+'.jpg',0)
        
        
    def action(self):
        self.state()
        self.train_input_data[self.current_state_index-1]=np.reshape(self.current_state,(2*self.line_length,2*self.line_length,self.frame_input_limit,1))
        self.current_output=self.model.predict(np.reshape(self.current_state,(1,2*self.line_length,2*self.line_length,self.frame_input_limit,1)))
        lt=[0]*int(self.decision_factor)+[1]*int(self.max_decision_factor-self.decision_factor)
        move_type=random.choice(lt)
        del lt
      
        if move_type==1:
            self.current_action=random.randint(0,1)
            
        else:
            if self.current_output[0][0]>=self.current_output[0][1]:
                self.current_action=0
                print('left')
            elif self.current_output[0][0]<self.current_output[0][1]:
                self.current_action=1
                print('right')
        
        
        if  self.current_state_index-2>=0:
            self.train_output_data[self.current_state_index-2]=self.current_output[0][self.current_action]+self.reward()/2-self.previous_output[0][self.previous_action]            
            
    
        self.previous_action=self.current_action
        self.previous_output=self.current_output
        
    def reward(self):
        if pi/2+self.angle/2>self.theta>pi/2-self.angle/2:
            return 1
        else:
            return -1
        
    def game_screen(self,screen,timer):
        screen.fill([0,0,50])
        pygame.time.delay(100)
        pygame.draw.rect(screen,(255,0,0),(0,325,400,75))

        for event in pygame.event.get():

            if event.type==pygame.QUIT:
                self.run=False

        if self.current_action==0:
            self.base_x-=self.base_velocity
            if self.base_x+self.base_width//2-self.line_length<0:
                self.base_x=400-self.base_width//2-self.line_length
            if self.theta>0 and self.theta<pi:
                self.theta-=0.1
            else:
                self.theta+=0.1
        else:
           
            self.base_x+=self.base_velocity
            if self.base_x+self.base_width//2+self.line_length>400:
                self.base_x=self.line_length-self.base_width//2

            if self.theta>0 and self.theta<pi:
                self.theta+=0.1

            else:
                self.theta-=0.1


        pygame.draw.rect(screen,(0,105,0),(self.base_x,self.base_y,self.base_width,self.base_height))
        font = pygame.font.Font('freesansbold.ttf', 20)
#        text = font.render(str(self.score)+'/'+str(timer), True, (0,0,0), (255,255,255))
        text = font.render('training time(frames)-'+str(timer), True, (0,0,0), (255,255,255))
        textRect = text.get_rect() 
        textRect.center = (200,20)
        screen.blit(text, textRect) 

        self.acceleration=0.7*cos(self.theta)
        self.velocity-=0.07*self.acceleration
        self.theta+=0.7*self.velocity
        self.theta=self.theta%(2*pi)
        


        self.line_top=(self.base_x+self.base_width//2 +self.line_length*cos(self.theta),self.base_y+self.base_height//2-self.line_length*sin(self.theta))

        line_base=(self.base_x+self.base_width//2,self.base_y+self.base_height//2)
        pygame.draw.line(screen,(255,255,255),line_base,self.line_top,5)
        pygame.display.update()

# %%
game=AI(game_time=800,replay_memory_limit=5,angle=pi/2,theta=pi/4,frame_input_limit=2,training_epochs=1,decision_factor=1,increment_factor=1,max_decision_factor=40)

# %%
pygame.init()
screen=pygame.display.set_mode((400,400))
pygame.display.set_caption('balance game')
game.run=True

timer=1
start=False
while game.run  :
    if start:

        if game.current_state_index<=game.replay_memory_limit+game.frame_input_limit-2:
            game.game_screen(screen,timer)
            game.get_screen(screen)
            game.action()
            game.current_state_index+=1

        else:
            if timer<=game.game_time*game.replay_memory_limit:
                game.train()
            


            game.current_state_index=0



        timer+=1
        game.score+=game.reward()
    else:
        for event in pygame.event.get():

            if event.type==pygame.KEYDOWN:
                start=True


pygame.quit()
# Out:
# Train on 5 samples
# 5/5 [==============================] - 1s 215ms/sample - loss: 0.0594 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 175ms/sample - loss: 0.1189 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.2965 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 179ms/sample - loss: 0.1393 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 178ms/sample - loss: 0.0897 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 179ms/sample - loss: 0.0717 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 180ms/sample - loss: 0.0553 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 178ms/sample - loss: 0.1080 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 181ms/sample - loss: 0.0334 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.1556 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 178ms/sample - loss: 0.0352 - accuracy: 1.0000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 177ms/sample - loss: 0.0468 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 181ms/sample - loss: 0.0837 - accuracy: 0.2000
# left
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 176ms/sample - loss: 0.0785 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0695 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 179ms/sample - loss: 0.0835 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 179ms/sample - loss: 0.2009 - accuracy: 1.0000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.1368 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.0521 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0412 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.0549 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0974 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0993 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 285ms/sample - loss: 0.0444 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0481 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0428 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.0446 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 183ms/sample - loss: 0.0444 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0467 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0504 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 183ms/sample - loss: 0.0510 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.0496 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.0497 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.0484 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 180ms/sample - loss: 0.0454 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.0446 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.0474 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 296ms/sample - loss: 0.0502 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0594 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0516 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0491 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0571 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0277 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0504 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.0353 - accuracy: 0.6000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0294 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0462 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.0491 - accuracy: 0.2000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0275 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 181ms/sample - loss: 0.0492 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0309 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 181ms/sample - loss: 0.0488 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 2s 304ms/sample - loss: 0.0279 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0235 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0548 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0464 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0521 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0264 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0389 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.6081 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.5457 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0371 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.1438 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0412 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 180ms/sample - loss: 0.0923 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.4123 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 202ms/sample - loss: 0.1001 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.0805 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0464 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0445 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0363 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0515 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0303 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0269 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0257 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0627 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.3974 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.6014 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.3099 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0804 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0499 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.4494 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.3101 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0874 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 2s 321ms/sample - loss: 0.0234 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.3654 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.1556 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0839 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0365 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.4098 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.2956 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0790 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0490 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.3682 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.3617 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0968 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0499 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.3865 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.1648 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0472 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.4222 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.1917 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0474 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.1737 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.3347 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0569 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 185ms/sample - loss: 0.0942 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.3175 - accuracy: 1.0000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.4016 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0447 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.1620 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.5163 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.3306 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0350 - accuracy: 0.2000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.0731 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.4114 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0849 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0561 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 2s 342ms/sample - loss: 0.0743 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.3536 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.3131 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 243ms/sample - loss: 0.1570 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0457 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.2661 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.2635 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0640 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.2695 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 204ms/sample - loss: 0.0921 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.2129 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 207ms/sample - loss: 0.1529 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.0916 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 206ms/sample - loss: 0.1319 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.4755 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 199ms/sample - loss: 0.0319 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.1531 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 216ms/sample - loss: 0.3352 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 211ms/sample - loss: 0.0570 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 210ms/sample - loss: 0.3016 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.3102 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 212ms/sample - loss: 0.0873 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 218ms/sample - loss: 0.3230 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.3399 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 220ms/sample - loss: 0.0851 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 225ms/sample - loss: 0.3665 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.2457 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 207ms/sample - loss: 0.0627 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 208ms/sample - loss: 0.2543 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 216ms/sample - loss: 0.1317 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 214ms/sample - loss: 0.0837 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 216ms/sample - loss: 0.0289 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.2540 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.6387 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 205ms/sample - loss: 0.1867 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 220ms/sample - loss: 0.3305 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 217ms/sample - loss: 0.1675 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.2824 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 221ms/sample - loss: 0.3319 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 218ms/sample - loss: 0.1513 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 228ms/sample - loss: 0.1683 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 225ms/sample - loss: 0.0407 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 218ms/sample - loss: 0.1070 - accuracy: 0.6000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 223ms/sample - loss: 0.0266 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 236ms/sample - loss: 0.2114 - accuracy: 0.8000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.2006 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0314 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 224ms/sample - loss: 0.5926 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 209ms/sample - loss: 0.1674 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 221ms/sample - loss: 0.0912 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 222ms/sample - loss: 0.3933 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 230ms/sample - loss: 0.0562 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 246ms/sample - loss: 0.3977 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 225ms/sample - loss: 0.3899 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 215ms/sample - loss: 0.1508 - accuracy: 0.2000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 252ms/sample - loss: 0.3525 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 230ms/sample - loss: 0.7218 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 2s 416ms/sample - loss: 0.2017 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 222ms/sample - loss: 0.0307 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 225ms/sample - loss: 0.1916 - accuracy: 0.8000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 226ms/sample - loss: 0.1800 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 246ms/sample - loss: 0.2454 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 202ms/sample - loss: 0.2127 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 203ms/sample - loss: 0.0183 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 205ms/sample - loss: 0.0205 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 205ms/sample - loss: 0.2578 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 210ms/sample - loss: 0.2581 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 207ms/sample - loss: 0.1778 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 206ms/sample - loss: 0.1110 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 206ms/sample - loss: 0.1046 - accuracy: 0.6000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 203ms/sample - loss: 0.2260 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 205ms/sample - loss: 0.2347 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 207ms/sample - loss: 0.0945 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.2119 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.1124 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.2034 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 208ms/sample - loss: 0.2073 - accuracy: 1.0000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 391ms/sample - loss: 0.1467 - accuracy: 1.0000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.1204 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 203ms/sample - loss: 0.0414 - accuracy: 1.0000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.4273 - accuracy: 0.2000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.0368 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.0258 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.1081 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.0455 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 199ms/sample - loss: 0.0250 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 201ms/sample - loss: 0.0177 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 201ms/sample - loss: 0.0861 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0166 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0210 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0074 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.0521 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0063 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0973 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.0213 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0478 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 203ms/sample - loss: 0.0227 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0450 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.0806 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.0448 - accuracy: 0.6000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0257 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 182ms/sample - loss: 0.0252 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 184ms/sample - loss: 0.0483 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0403 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0266 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0386 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0327 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 189ms/sample - loss: 0.0281 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.0483 - accuracy: 1.0000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 204ms/sample - loss: 0.0257 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.0237 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0219 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.0177 - accuracy: 0.6000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0442 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0203 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0199 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 210ms/sample - loss: 0.0323 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0178 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0195 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0193 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0756 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 190ms/sample - loss: 0.0172 - accuracy: 0.8000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 199ms/sample - loss: 0.0187 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0191 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 208ms/sample - loss: 0.0178 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0278 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 199ms/sample - loss: 0.0155 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0759 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0177 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0175 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.0415 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 186ms/sample - loss: 0.0155 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 202ms/sample - loss: 0.5927 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 197ms/sample - loss: 0.1266 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.0452 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0207 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.0829 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.2842 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 183ms/sample - loss: 0.3864 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.1470 - accuracy: 0.8000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 417ms/sample - loss: 0.1345 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0487 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 207ms/sample - loss: 0.5012 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 188ms/sample - loss: 0.5737 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0343 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 206ms/sample - loss: 0.0479 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.0705 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.3585 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.1015 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.0215 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0567 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.2887 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.1666 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.0429 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.0428 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0413 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.2786 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.1634 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 199ms/sample - loss: 0.0645 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0421 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 200ms/sample - loss: 0.7469 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.5508 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 2s 432ms/sample - loss: 0.1126 - accuracy: 0.0000e+00
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 204ms/sample - loss: 0.0489 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 196ms/sample - loss: 0.0448 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.5704 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 203ms/sample - loss: 0.0531 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 193ms/sample - loss: 0.0492 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 187ms/sample - loss: 0.5499 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 191ms/sample - loss: 0.4952 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0655 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 209ms/sample - loss: 0.0368 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.3405 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 201ms/sample - loss: 0.4435 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 198ms/sample - loss: 0.1074 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 192ms/sample - loss: 0.0425 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 194ms/sample - loss: 0.0873 - accuracy: 0.6000
# right
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.4331 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 208ms/sample - loss: 0.1005 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 216ms/sample - loss: 0.0365 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 209ms/sample - loss: 0.3968 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 217ms/sample - loss: 0.2669 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 195ms/sample - loss: 0.1561 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 2s 309ms/sample - loss: 0.1449 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 220ms/sample - loss: 0.2126 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 2s 481ms/sample - loss: 0.2305 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.1798 - accuracy: 0.4000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 222ms/sample - loss: 0.0177 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 215ms/sample - loss: 0.0225 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 219ms/sample - loss: 0.1452 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 223ms/sample - loss: 0.3459 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 1s 240ms/sample - loss: 0.3049 - accuracy: 0.2000
# Train on 5 samples
# 5/5 [==============================] - 1s 237ms/sample - loss: 0.1495 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 224ms/sample - loss: 0.1174 - accuracy: 0.4000
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 233ms/sample - loss: 0.0498 - accuracy: 1.0000
# left
# left
# Train on 5 samples
# 5/5 [==============================] - 1s 250ms/sample - loss: 0.0364 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 272ms/sample - loss: 0.0258 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 245ms/sample - loss: 0.0191 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 220ms/sample - loss: 0.1449 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 297ms/sample - loss: 0.0237 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 2s 337ms/sample - loss: 0.0212 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 2s 398ms/sample - loss: 0.1383 - accuracy: 0.6000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 349ms/sample - loss: 0.0270 - accuracy: 0.8000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 428ms/sample - loss: 0.0224 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 2s 340ms/sample - loss: 0.0242 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 3s 561ms/sample - loss: 0.3873 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 266ms/sample - loss: 0.2407 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 3s 556ms/sample - loss: 0.2338 - accuracy: 0.0000e+00
# Train on 5 samples
# 5/5 [==============================] - 6s 1s/sample - loss: 0.2323 - accuracy: 0.2000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 447ms/sample - loss: 0.0979 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 2s 349ms/sample - loss: 0.0710 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 264ms/sample - loss: 0.0389 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 271ms/sample - loss: 0.0202 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 213ms/sample - loss: 0.0431 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 2s 355ms/sample - loss: 0.0964 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 234ms/sample - loss: 0.0201 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 258ms/sample - loss: 0.0197 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 259ms/sample - loss: 0.0677 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 1s 233ms/sample - loss: 0.0201 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 283ms/sample - loss: 0.0198 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 2s 351ms/sample - loss: 0.0232 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 2s 378ms/sample - loss: 0.0496 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 273ms/sample - loss: 0.0124 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 236ms/sample - loss: 0.0448 - accuracy: 0.6000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 242ms/sample - loss: 0.1043 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 3s 644ms/sample - loss: 0.0219 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 269ms/sample - loss: 0.0260 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 232ms/sample - loss: 0.0253 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 224ms/sample - loss: 0.1417 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 275ms/sample - loss: 0.0052 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 1s 229ms/sample - loss: 0.0737 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 241ms/sample - loss: 0.0233 - accuracy: 0.8000
# Train on 5 samples
# 5/5 [==============================] - 1s 289ms/sample - loss: 0.0219 - accuracy: 1.0000
# Train on 5 samples
# 5/5 [==============================] - 1s 273ms/sample - loss: 0.0168 - accuracy: 0.8000
# left
# Train on 5 samples
# 5/5 [==============================] - 2s 300ms/sample - loss: 0.1277 - accuracy: 0.2000
# right
# Train on 5 samples
# 5/5 [==============================] - 1s 202ms/sample - loss: 0.0481 - accuracy: 0.4000
# Train on 5 samples
# 5/5 [==============================] - 2s 301ms/sample - loss: 0.0361 - accuracy: 0.6000
# Train on 5 samples
# 5/5 [==============================] - 4s 851ms/sample - loss: 0.1141 - accuracy: 0.2000

# %%
pygame.quit()

# %%
del game
